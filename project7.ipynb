# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis

# %%
data = pd.read_csv('data.csv')
data.columns = data.columns.str.strip()
data.rename(columns={'Debt ratio %': 'Debt_ratio'}, inplace=True)

# %%
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                   1
# 1                                           0.570175                   1
# 2                                           0.563706                   1
# 3                                           0.564663                   1
# 4                                           0.575617                   1
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
data.shape
# Out:
# (6819, 96)

# %%
data.isna().sum().head(50)
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#  Realized Sales Gross Margin                                0
#  Operating Profit Rate                                      0
#  Pre-tax net Interest Rate                                  0
#  After-tax net Interest Rate                                0
#  Non-industry income and expenditure/revenue                0
#  Continuous interest rate (after tax)                       0
#  Operating Expense Rate                                     0
#  Research and development expense rate                      0
#  Cash flow rate                                             0
#  Interest-bearing debt interest rate                        0
#  Tax rate (A)                                               0
#  Net Value Per Share (B)                                    0
#  Net Value Per Share (A)                                    0
#  Net Value Per Share (C)                                    0
#  Persistent EPS in the Last Four Seasons                    0
#  Cash Flow Per Share                                        0
#  Revenue Per Share (Yuan ¥)                                 0
#  Operating Profit Per Share (Yuan ¥)                        0
#  Per Share Net profit before tax (Yuan ¥)                   0
#  Realized Sales Gross Profit Growth Rate                    0
#  Operating Profit Growth Rate                               0
#  After-tax Net Profit Growth Rate                           0
#  Regular Net Profit Growth Rate                             0
#  Continuous Net Profit Growth Rate                          0
#  Total Asset Growth Rate                                    0
#  Net Value Growth Rate                                      0
#  Total Asset Return Growth Rate Ratio                       0
#  Cash Reinvestment %                                        0
#  Current Ratio                                              0
#  Quick Ratio                                                0
#  Interest Expense Ratio                                     0
#  Total debt/Total net worth                                 0
#  Debt ratio %                                               0
#  Net worth/Assets                                           0
#  Long-term fund suitability ratio (A)                       0
#  Borrowing dependency                                       0
#  Contingent liabilities/Net worth                           0
#  Operating profit/Paid-in capital                           0
#  Net profit before tax/Paid-in capital                      0
#  Inventory and accounts receivable/Net value                0
#  Total Asset Turnover                                       0
#  Accounts Receivable Turnover                               0
#  Average Collection Days                                    0
#  Inventory Turnover Rate (times)                            0
#  Fixed Assets Turnover Frequency                            0
# dtype: int64

# %%
data.dtypes.tail(50)
# Out:
#  Accounts Receivable Turnover                          float64
#  Average Collection Days                               float64
#  Inventory Turnover Rate (times)                       float64
#  Fixed Assets Turnover Frequency                       float64
#  Net Worth Turnover Rate (times)                       float64
#  Revenue per person                                    float64
#  Operating profit per person                           float64
#  Allocation rate per person                            float64
#  Working Capital to Total Assets                       float64
#  Quick Assets/Total Assets                             float64
#  Current Assets/Total Assets                           float64
#  Cash/Total Assets                                     float64
#  Quick Assets/Current Liability                        float64
#  Cash/Current Liability                                float64
#  Current Liability to Assets                           float64
#  Operating Funds to Liability                          float64
#  Inventory/Working Capital                             float64
#  Inventory/Current Liability                           float64
#  Current Liabilities/Liability                         float64
#  Working Capital/Equity                                float64
#  Current Liabilities/Equity                            float64
#  Long-term Liability to Current Assets                 float64
#  Retained Earnings to Total Assets                     float64
#  Total income/Total expense                            float64
#  Total expense/Assets                                  float64
#  Current Asset Turnover Rate                           float64
#  Quick Asset Turnover Rate                             float64
#  Working capitcal Turnover Rate                        float64
#  Cash Turnover Rate                                    float64
#  Cash Flow to Sales                                    float64
#  Fixed Assets to Assets                                float64
#  Current Liability to Liability                        float64
#  Current Liability to Equity                           float64
#  Equity to Long-term Liability                         float64
#  Cash Flow to Total Assets                             float64
#  Cash Flow to Liability                                float64
#  CFO to Assets                                         float64
#  Cash Flow to Equity                                   float64
#  Current Liability to Current Assets                   float64
#  Liability-Assets Flag                                   int64
#  Net Income to Total Assets                            float64
#  Total assets to GNP price                             float64
#  No-credit Interval                                    float64
#  Gross Profit to Sales                                 float64
#  Net Income to Stockholder's Equity                    float64
#  Liability to Equity                                   float64
#  Degree of Financial Leverage (DFL)                    float64
#  Interest Coverage Ratio (Interest expense to EBIT)    float64
#  Net Income Flag                                         int64
#  Equity to Liability                                   float64
# dtype: object

# %%
data.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   6819.000000  ...
# mean                                       0.303623  ...
# std                                        0.011163  ...
# min                                        0.000000  ...
# 25%                                        0.303466  ...
# 50%                                        0.303525  ...
# 75%                                        0.303585  ...
# max                                        1.000000  ...
#
#         Net Income to Total Assets   Total assets to GNP price  \
# count                  6819.000000                6.819000e+03
# mean                      0.807760                1.862942e+07
# std                       0.040332                3.764501e+08
# min                       0.000000                0.000000e+00
# 25%                       0.796750                9.036205e-04
# 50%                       0.810619                2.085213e-03
# 75%                       0.826455                5.269777e-03
# max                       1.000000                9.820000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          6819.000000             6819.000000
# mean              0.623915                0.607946
# std               0.012290                0.016934
# min               0.000000                0.000000
# 25%               0.623636                0.600443
# 50%               0.623879                0.605998
# 75%               0.624168                0.613913
# max               1.000000                1.000000
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          6819.000000           6819.000000
# mean                              0.840402              0.280365
# std                               0.014523              0.014463
# min                               0.000000              0.000000
# 25%                               0.840115              0.276944
# 50%                               0.841179              0.278778
# 75%                               0.842357              0.281449
# max                               1.000000              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          6819.000000
# mean                              0.027541
# std                               0.015668
# min                               0.000000
# 25%                               0.026791
# 50%                               0.026808
# 75%                               0.026913
# max                               1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        6819.000000              6819.0
# mean                                            0.565358                 1.0
# std                                             0.013214                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565252                 1.0
# 75%                                             0.565725                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability
# count           6819.000000
# mean               0.047578
# std                0.050014
# min                0.000000
# 25%                0.024477
# 50%                0.033798
# 75%                0.052838
# max                1.000000
#
# [8 rows x 96 columns]

# %%
data.hist(figsize=(40, 40), bins=30, xlabelsize=10, ylabelsize=10)
# Out:
# array([[<Axes: title={'center': 'Bankrupt?'}>,
#         <Axes: title={'center': ' ROA(C) before interest and depreciation before interest'}>,
#         <Axes: title={'center': ' ROA(A) before interest and % after tax'}>,
#         <Axes: title={'center': ' ROA(B) before interest and depreciation after tax'}>,
#         <Axes: title={'center': ' Operating Gross Margin'}>,
#         <Axes: title={'center': ' Realized Sales Gross Margin'}>,
#         <Axes: title={'center': ' Operating Profit Rate'}>,
#         <Axes: title={'center': ' Pre-tax net Interest Rate'}>,
#         <Axes: title={'center': ' After-tax net Interest Rate'}>,
#         <Axes: title={'center': ' Non-industry income and expenditure/revenue'}>],
#        [<Axes: title={'center': ' Continuous interest rate (after tax)'}>,
#         <Axes: title={'center': ' Operating Expense Rate'}>,
#         <Axes: title={'center': ' Research and development expense rate'}>,
#         <Axes: title={'center': ' Cash flow rate'}>,
#         <Axes: title={'center': ' Interest-bearing debt interest rate'}>,
#         <Axes: title={'center': ' Tax rate (A)'}>,
#         <Axes: title={'center': ' Net Value Per Share (B)'}>,
#         <Axes: title={'center': ' Net Value Per Share (A)'}>,
#         <Axes: title={'center': ' Net Value Per Share (C)'}>,
#         <Axes: title={'center': ' Persistent EPS in the Last Four Seasons'}>],
#        [<Axes: title={'center': ' Cash Flow Per Share'}>,
#         <Axes: title={'center': ' Revenue Per Share (Yuan ¥)'}>,
#         <Axes: title={'center': ' Operating Profit Per Share (Yuan ¥)'}>,
#         <Axes: title={'center': ' Per Share Net profit before tax (Yuan ¥)'}>,
#         <Axes: title={'center': ' Realized Sales Gross Profit Growth Rate'}>,
#         <Axes: title={'center': ' Operating Profit Growth Rate'}>,
#         <Axes: title={'center': ' After-tax Net Profit Growth Rate'}>,
#         <Axes: title={'center': ' Regular Net Profit Growth Rate'}>,
#         <Axes: title={'center': ' Continuous Net Profit Growth Rate'}>,
#         <Axes: title={'center': ' Total Asset Growth Rate'}>],
#        [<Axes: title={'center': ' Net Value Growth Rate'}>,
#         <Axes: title={'center': ' Total Asset Return Growth Rate Ratio'}>,
#         <Axes: title={'center': ' Cash Reinvestment %'}>,
#         <Axes: title={'center': ' Current Ratio'}>,
#         <Axes: title={'center': ' Quick Ratio'}>,
#         <Axes: title={'center': ' Interest Expense Ratio'}>,
#         <Axes: title={'center': ' Total debt/Total net worth'}>,
#         <Axes: title={'center': ' Debt ratio %'}>,
#         <Axes: title={'center': ' Net worth/Assets'}>,
#         <Axes: title={'center': ' Long-term fund suitability ratio (A)'}>],
#        [<Axes: title={'center': ' Borrowing dependency'}>,
#         <Axes: title={'center': ' Contingent liabilities/Net worth'}>,
#         <Axes: title={'center': ' Operating profit/Paid-in capital'}>,
#         <Axes: title={'center': ' Net profit before tax/Paid-in capital'}>,
#         <Axes: title={'center': ' Inventory and accounts receivable/Net value'}>,
#         <Axes: title={'center': ' Total Asset Turnover'}>,
#         <Axes: title={'center': ' Accounts Receivable Turnover'}>,
#         <Axes: title={'center': ' Average Collection Days'}>,
#         <Axes: title={'center': ' Inventory Turnover Rate (times)'}>,
#         <Axes: title={'center': ' Fixed Assets Turnover Frequency'}>],
#        [<Axes: title={'center': ' Net Worth Turnover Rate (times)'}>,
#         <Axes: title={'center': ' Revenue per person'}>,
#         <Axes: title={'center': ' Operating profit per person'}>,
#         <Axes: title={'center': ' Allocation rate per person'}>,
#         <Axes: title={'center': ' Working Capital to Total Assets'}>,
#         <Axes: title={'center': ' Quick Assets/Total Assets'}>,
#         <Axes: title={'center': ' Current Assets/Total Assets'}>,
#         <Axes: title={'center': ' Cash/Total Assets'}>,
#         <Axes: title={'center': ' Quick Assets/Current Liability'}>,
#         <Axes: title={'center': ' Cash/Current Liability'}>],
#        [<Axes: title={'center': ' Current Liability to Assets'}>,
#         <Axes: title={'center': ' Operating Funds to Liability'}>,
#         <Axes: title={'center': ' Inventory/Working Capital'}>,
#         <Axes: title={'center': ' Inventory/Current Liability'}>,
#         <Axes: title={'center': ' Current Liabilities/Liability'}>,
#         <Axes: title={'center': ' Working Capital/Equity'}>,
#         <Axes: title={'center': ' Current Liabilities/Equity'}>,
#         <Axes: title={'center': ' Long-term Liability to Current Assets'}>,
#         <Axes: title={'center': ' Retained Earnings to Total Assets'}>,
#         <Axes: title={'center': ' Total income/Total expense'}>],
#        [<Axes: title={'center': ' Total expense/Assets'}>,
#         <Axes: title={'center': ' Current Asset Turnover Rate'}>,
#         <Axes: title={'center': ' Quick Asset Turnover Rate'}>,
#         <Axes: title={'center': ' Working capitcal Turnover Rate'}>,
#         <Axes: title={'center': ' Cash Turnover Rate'}>,
#         <Axes: title={'center': ' Cash Flow to Sales'}>,
#         <Axes: title={'center': ' Fixed Assets to Assets'}>,
#         <Axes: title={'center': ' Current Liability to Liability'}>,
#         <Axes: title={'center': ' Current Liability to Equity'}>,
#         <Axes: title={'center': ' Equity to Long-term Liability'}>],
#        [<Axes: title={'center': ' Cash Flow to Total Assets'}>,
#         <Axes: title={'center': ' Cash Flow to Liability'}>,
#         <Axes: title={'center': ' CFO to Assets'}>,
#         <Axes: title={'center': ' Cash Flow to Equity'}>,
#         <Axes: title={'center': ' Current Liability to Current Assets'}>,
#         <Axes: title={'center': ' Liability-Assets Flag'}>,
#         <Axes: title={'center': ' Net Income to Total Assets'}>,
#         <Axes: title={'center': ' Total assets to GNP price'}>,
#         <Axes: title={'center': ' No-credit Interval'}>,
#         <Axes: title={'center': ' Gross Profit to Sales'}>],
#        [<Axes: title={'center': " Net Income to Stockholder's Equity"}>,
#         <Axes: title={'center': ' Liability to Equity'}>,
#         <Axes: title={'center': ' Degree of Financial Leverage (DFL)'}>,
#         <Axes: title={'center': ' Interest Coverage Ratio (Interest expense to EBIT)'}>,
#         <Axes: title={'center': ' Net Income Flag'}>,
#         <Axes: title={'center': ' Equity to Liability'}>, <Axes: >,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
data['Bankrupt?'].value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %%
220/6599
# Out:
# 0.03333838460372784

# %%
correlations_matrix = data.corr()
bankruptcy_correlations = correlations_matrix['Bankrupt?'].sort_values()

# %%
bankruptcy_correlations.head(10)
# Out:
#  Net Income to Total Assets                                -0.315457
#  ROA(A) before interest and % after tax                    -0.282941
#  ROA(B) before interest and depreciation after tax         -0.273051
#  ROA(C) before interest and depreciation before interest   -0.260807
#  Net worth/Assets                                          -0.250161
#  Persistent EPS in the Last Four Seasons                   -0.219560
#  Retained Earnings to Total Assets                         -0.217779
#  Net profit before tax/Paid-in capital                     -0.207857
#  Per Share Net profit before tax (Yuan ¥)                  -0.201395
#  Working Capital to Total Assets                           -0.193083
# Name: Bankrupt?, dtype: float64

# %%
bankruptcy_correlations.tail(10)
# Out:
#  Liability-Assets Flag                  0.139212
#  Current Liability to Equity            0.153828
#  Current Liabilities/Equity             0.153828
#  Liability to Equity                    0.166812
#  Current Liability to Current Assets    0.171306
#  Borrowing dependency                   0.176543
#  Current Liability to Assets            0.194494
#  Debt ratio %                           0.250161
# Bankrupt?                               1.000000
#  Net Income Flag                             NaN
# Name: Bankrupt?, dtype: float64

# %%
# List of y-values for the boxplots
y_values = ['Debt_ratio','Current Liability to Assets' , 'Borrowing dependency', 'Current Liability to Current Assets', 'Net Income to Total Assets', 'ROA(A) before interest and % after tax', 'Net worth/Assets', 'Persistent EPS in the Last Four Seasons','Retained Earnings to Total Assets','Net profit before tax/Paid-in capital']

# Create a subplot grid with 2 rows and 5 columns
fig, axes = plt.subplots(2, 5, figsize=(15, 8))

# Flatten the axes array for easier iteration
axes = axes.flatten()

# Iterate through the y-values and plot boxplots
for i, y in enumerate(y_values):
    # Select the current subplot
    ax = axes[i]
    
    # Plot the boxplot using Seaborn
    sns.boxplot(data=data, x='Bankrupt?', y=y, palette="coolwarm", ax=ax)
    
    # Set the title for the subplot
    ax.set_title(f'{y}')
    
    # Set x-axis label
    ax.set_xlabel('Bankrupt?')
    
    # Set y-axis label
    ax.set_ylabel(y)

# Adjust the layout of the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Create a pivot table to summarize the metrics for each column and Bankrupt? value
summary_table = data.pivot_table(index='Bankrupt?', values=['Debt_ratio','Current Liability to Assets' , 'Borrowing dependency', 'Current Liability to Current Assets', 'Net Income to Total Assets', 'ROA(A) before interest and % after tax', 'Net worth/Assets', 'Persistent EPS in the Last Four Seasons','Retained Earnings to Total Assets','Net profit before tax/Paid-in capital'], aggfunc='describe')
summary_table = summary_table.transpose()
pd.set_option('display.max_rows', 80)


# Display the summary table
display(summary_table)
# Out:
# Bankrupt?                                                0           1
# Borrowing dependency                    25%       0.370124    0.377721
#                                         50%       0.372474    0.382655
#                                         75%       0.375940    0.388750
#                                         count  6599.000000  220.000000
#                                         max       0.887435    1.000000
#                                         mean      0.374129    0.390400
#                                         min       0.187124    0.000000
#                                         std       0.009480    0.072752
# Current Liability to Assets             25%       0.052540    0.103332
#                                         50%       0.081072    0.145603
#                                         75%       0.117064    0.181571
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.343143
#                                         mean      0.088887    0.144238
#                                         min       0.000000    0.005163
#                                         std       0.049025    0.057854
# Current Liability to Current Assets     25%       0.017757    0.036122
#                                         50%       0.027133    0.047675
#                                         75%       0.037549    0.070487
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.460675
#                                         mean      0.030542    0.060443
#                                         min       0.000000    0.002507
#                                         std       0.029684    0.046929
# Debt_ratio                              25%       0.071560    0.158728
#                                         50%       0.109381    0.187426
#                                         75%       0.145796    0.214280
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.525410
#                                         mean      0.110714    0.187047
#                                         min       0.000000    0.001088
#                                         std       0.052071    0.056234
# Net Income to Total Assets              25%       0.797819    0.719248
#                                         50%       0.811492    0.766297
#                                         75%       0.827158    0.789621
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.819091
#                                         mean      0.810083    0.738083
#                                         min       0.000000    0.411809
#                                         std       0.035991    0.081092
# Net profit before tax/Paid-in capital   25%       0.169942    0.137635
#                                         50%       0.179021    0.154012
#                                         75%       0.192203    0.165393
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.197647
#                                         mean      0.183883    0.147672
#                                         min       0.052439    0.000000
#                                         std       0.030211    0.027048
# Net worth/Assets                        25%       0.854204    0.785720
#                                         50%       0.890619    0.812574
#                                         75%       0.928440    0.841272
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.998912
#                                         mean      0.889286    0.812953
#                                         min       0.000000    0.474590
#                                         std       0.052071    0.056234
# Persistent EPS in the Last Four Seasons 25%       0.215278    0.176397
#                                         50%       0.225111    0.195944
#                                         75%       0.239671    0.208944
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.252529
#                                         mean      0.230146    0.188818
#                                         min       0.078567    0.000000
#                                         std       0.032510    0.030709
# ROA(A) before interest and % after tax  25%       0.537724    0.431531
#                                         50%       0.561219    0.490215
#                                         75%       0.590438    0.526630
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.582861
#                                         mean      0.562015    0.456947
#                                         min       0.006923    0.000000
#                                         std       0.060898    0.107674
# Retained Earnings to Total Assets       25%       0.931820    0.894705
#                                         50%       0.938058    0.912923
#                                         75%       0.945127    0.928370
#                                         count  6599.000000  220.000000
#                                         max       1.000000    0.955245
#                                         mean      0.935749    0.904244
#                                         min       0.000000    0.729196
#                                         std       0.024538    0.035218

# %%
# Select the ten columns
columns_of_interest = ['Debt_ratio','Current Liability to Assets' , 'Borrowing dependency', 'Current Liability to Current Assets', 'Net Income to Total Assets', 'ROA(A) before interest and % after tax', 'Net worth/Assets', 'Persistent EPS in the Last Four Seasons','Retained Earnings to Total Assets','Net profit before tax/Paid-in capital']

# Create a new DataFrame with only the columns of interest and 'Bankrupt?' column
subset_data = data[columns_of_interest + ['Bankrupt?']]

# Group the data by 'Bankrupt?' and calculate the means for each column
mean_data = subset_data.groupby('Bankrupt?')[columns_of_interest].mean()

# Reset the 'Bankrupt?' index to make it a column for plotting
mean_data = mean_data.reset_index()

# Melt the data to create a "long" form for easy plotting
melted_data = mean_data.melt(id_vars='Bankrupt?', var_name='Column', value_name='Mean')

# Convert 'Bankrupt?' column to string type
melted_data['Bankrupt?'] = melted_data['Bankrupt?'].astype(str)

# Plot the means using Seaborn barplot
sns.barplot(data=melted_data, x='Column', y='Mean', hue='Bankrupt?', palette='coolwarm')

# Set the title and labels
plt.title('Means for Bankrupt? = 0 and Bankrupt? = 1')
plt.xlabel('Columns')
plt.ylabel('Mean')

# Rotate the x-axis labels vertically
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %%
# Select the ten columns
columns_of_interest = ['Debt_ratio','Current Liability to Assets' , 'Borrowing dependency', 'Current Liability to Current Assets', 'Net Income to Total Assets', 'ROA(A) before interest and % after tax', 'Net worth/Assets', 'Persistent EPS in the Last Four Seasons','Retained Earnings to Total Assets','Net profit before tax/Paid-in capital']

# Create a new DataFrame with only the columns of interest and 'Bankrupt?' column
subset_data = data[columns_of_interest + ['Bankrupt?']]

# Group the data by 'Bankrupt?' and calculate the means for each column
mean_data = subset_data.groupby('Bankrupt?')[columns_of_interest].median()

# Reset the 'Bankrupt?' index to make it a column for plotting
mean_data = mean_data.reset_index()

# Melt the data to create a "long" form for easy plotting
melted_data = mean_data.melt(id_vars='Bankrupt?', var_name='Column', value_name='Median')

# Convert 'Bankrupt?' column to string type
melted_data['Bankrupt?'] = melted_data['Bankrupt?'].astype(str)

# Plot the means using Seaborn barplot
sns.barplot(data=melted_data, x='Column', y='Median', hue='Bankrupt?', palette='coolwarm')

# Set the title and labels
plt.title('Medians for Bankrupt? = 0 and Bankrupt? = 1')
plt.xlabel('Columns')
plt.ylabel('Median')

# Rotate the x-axis labels vertically
plt.xticks(rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# #Analysis:
# - the dataset is cleaned (with no null values) and with 90+ numerical variable already scaled
# - certain variables have a close name
# - the univariate analysis indicates that:
#     - Lots of variable seems to have a very low variance, so may be removed for improving model performance
#     - some of them seems to be highly correlated, so may potentialy be removed too
# - Correlation analysis with the Target (Bankrupt?) indicates that:
#     - None of the variable seems to be highly correlated with the target
#     - several are moderately correlated
#  - Bivariate analysis of the variable that are more correlated with the Target indicates that:
#     - Debt Ratio seems to be the most related variables
#     - ROA A, Current Liability to Assets, Net worth/Assets, Net Income to Total Assets seem also to be related too
#     - With a lower variance, Persistent EPS in the Last Four Seasons seems also to be related relatively significantly
#     - NB: for several variables we can see that there only outliers in on side for Bankrupt whereas there are in both side for no bankrupt
#
# - Additionaly, a hypothesis testing on Debt Ratio can be useful to conduct.

# %% [markdown]
# # Feature Selection & Reduction

# %% [markdown]
# ## 1.  Dropping highly correlated Features

# %%
correlations_matrix = data.corr()
fig, ax = plt.subplots(figsize=(10, 8))
g = sns.heatmap(correlations_matrix, annot=True)
for tick_label in g.axes.get_yticklabels():
    tick_label.set_color("grey")
    tick_label.set_fontsize("10")
for tick_label in g.axes.get_xticklabels():
    tick_label.set_color("grey")
    tick_label.set_fontsize("10")
plt.show()
# Out:
# /Users/pierremenard/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
high_corr_threshold = 0.8
highly_correlated_pairs = []

for i in range(len(correlations_matrix.columns)):
    for j in range(i):
        if abs(correlations_matrix.iloc[i, j]) > high_corr_threshold:
            col_pair = (correlations_matrix.columns[i], correlations_matrix.columns[j], correlations_matrix.iloc[i, j])
            highly_correlated_pairs.append(col_pair)

for pair in highly_correlated_pairs:
    print(f"Columns: {pair[0]} and {pair[1]} - Correlation: {pair[2]}")
# Out:
# Columns: ROA(A) before interest and % after tax and ROA(C) before interest and depreciation before interest - Correlation: 0.940123707970081
# Columns: ROA(B) before interest and depreciation after tax and ROA(C) before interest and depreciation before interest - Correlation: 0.9868494970182545
# Columns: ROA(B) before interest and depreciation after tax and ROA(A) before interest and % after tax - Correlation: 0.9557406252835045
# Columns: Realized Sales Gross Margin and Operating Gross Margin - Correlation: 0.9995182781255225
# Columns: Pre-tax net Interest Rate and Operating Profit Rate - Correlation: 0.9164477798560053
# Columns: After-tax net Interest Rate and Operating Profit Rate - Correlation: 0.8621907071596802
# Columns: After-tax net Interest Rate and Pre-tax net Interest Rate - Correlation: 0.986379024258203
# Columns: Continuous interest rate (after tax) and Operating Profit Rate - Correlation: 0.9155437834862156
# Columns: Continuous interest rate (after tax) and Pre-tax net Interest Rate - Correlation: 0.9936165193085659
# Columns: Continuous interest rate (after tax) and After-tax net Interest Rate - Correlation: 0.9844523287759168
# Columns: Net Value Per Share (A) and Net Value Per Share (B) - Correlation: 0.9993420298970492
# Columns: Net Value Per Share (C) and Net Value Per Share (B) - Correlation: 0.9991785547277326
# Columns: Net Value Per Share (C) and Net Value Per Share (A) - Correlation: 0.9998372673766628
# Columns: Operating Profit Per Share (Yuan ¥) and Persistent EPS in the Last Four Seasons - Correlation: 0.8767694890496592
# Columns: Per Share Net profit before tax (Yuan ¥) and Persistent EPS in the Last Four Seasons - Correlation: 0.9555910456161516
# Columns: Per Share Net profit before tax (Yuan ¥) and Operating Profit Per Share (Yuan ¥) - Correlation: 0.861812562331303
# Columns: Regular Net Profit Growth Rate and After-tax Net Profit Growth Rate - Correlation: 0.9961861926223089
# Columns: Net worth/Assets and Debt_ratio - Correlation: -0.9999999999999993
# Columns: Operating profit/Paid-in capital and Persistent EPS in the Last Four Seasons - Correlation: 0.8736405203664436
# Columns: Operating profit/Paid-in capital and Operating Profit Per Share (Yuan ¥) - Correlation: 0.9986961505784386
# Columns: Operating profit/Paid-in capital and Per Share Net profit before tax (Yuan ¥) - Correlation: 0.8583102552070087
# Columns: Net profit before tax/Paid-in capital and Persistent EPS in the Last Four Seasons - Correlation: 0.9594608424800604
# Columns: Net profit before tax/Paid-in capital and Operating Profit Per Share (Yuan ¥) - Correlation: 0.8861573968367281
# Columns: Net profit before tax/Paid-in capital and Per Share Net profit before tax (Yuan ¥) - Correlation: 0.962722888955671
# Columns: Net profit before tax/Paid-in capital and Operating profit/Paid-in capital - Correlation: 0.8873704466151631
# Columns: Current Liability to Assets and Debt_ratio - Correlation: 0.8425830280709252
# Columns: Current Liability to Assets and Net worth/Assets - Correlation: -0.8425830280709209
# Columns: Operating Funds to Liability and Cash flow rate - Correlation: 0.8805618326815656
# Columns: Current Liabilities/Equity and Borrowing dependency - Correlation: 0.8927718551578726
# Columns: Cash Flow to Sales and Working capitcal Turnover Rate - Correlation: 0.9481940614911444
# Columns: Current Liability to Liability and Current Liabilities/Liability - Correlation: 1.0
# Columns: Current Liability to Equity and Borrowing dependency - Correlation: 0.8927718551578726
# Columns: Current Liability to Equity and Current Liabilities/Equity - Correlation: 1.0
# Columns: Equity to Long-term Liability and Borrowing dependency - Correlation: 0.8068892480541348
# Columns: Net Income to Total Assets and ROA(C) before interest and depreciation before interest - Correlation: 0.8876695382909835
# Columns: Net Income to Total Assets and ROA(A) before interest and % after tax - Correlation: 0.9615519166312981
# Columns: Net Income to Total Assets and ROA(B) before interest and depreciation after tax - Correlation: 0.912040173335215
# Columns: Gross Profit to Sales and Operating Gross Margin - Correlation: 0.9999999924887605
# Columns: Gross Profit to Sales and Realized Sales Gross Margin - Correlation: 0.9995182260040114
# Columns: Net Income to Stockholder's Equity and Borrowing dependency - Correlation: -0.8064782406650233
# Columns: Liability to Equity and Borrowing dependency - Correlation: 0.9558567721071973
# Columns: Liability to Equity and Current Liabilities/Equity - Correlation: 0.9639083871660641
# Columns: Liability to Equity and Current Liability to Equity - Correlation: 0.9639083871660641

# %%
import pandas as pd

high_corr_threshold = 0.7
columns_to_drop = set()  

for i in range(len(correlations_matrix.columns)):
    for j in range(i):
        if abs(correlations_matrix.iloc[i, j]) > high_corr_threshold:
          
            col_to_drop = correlations_matrix.columns[i]
            columns_to_drop.add(col_to_drop)


data_dropped = data.drop(columns=columns_to_drop, errors='ignore') 
print(f"Dropping columns: {columns_to_drop}")
# Out:
# Dropping columns: {'Net Value Per Share (A)', 'Net Value Per Share (C)', 'Current Liability to Assets', 'Regular Net Profit Growth Rate', 'Net Worth Turnover Rate (times)', "Net Income to Stockholder's Equity", 'Gross Profit to Sales', 'Current Liability to Equity', 'Current Liabilities/Equity', 'Net Income to Total Assets', 'Liability to Equity', 'Inventory and accounts receivable/Net value', 'Cash Flow to Liability', 'ROA(B) before interest and depreciation after tax', 'Continuous interest rate (after tax)', 'Pre-tax net Interest Rate', 'CFO to Assets', 'After-tax net Interest Rate', 'Working capitcal Turnover Rate', 'Realized Sales Gross Margin', 'Operating Funds to Liability', 'ROA(A) before interest and % after tax', 'Net profit before tax/Paid-in capital', 'Operating Profit Per Share (Yuan ¥)', 'Net worth/Assets', 'Per Share Net profit before tax (Yuan ¥)', 'Cash Flow to Sales', 'Current Assets/Total Assets', 'Operating profit/Paid-in capital', 'Retained Earnings to Total Assets', 'Working Capital/Equity', 'Persistent EPS in the Last Four Seasons', 'Current Liability to Liability', 'Equity to Long-term Liability'}

# %%
data_dropped
# Out:
#       Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#       Operating Gross Margin  Operating Profit Rate  \
# 0                   0.601457               0.998969
# 1                   0.610235               0.998946
# 2                   0.601450               0.998857
# 3                   0.583541               0.998700
# 4                   0.598783               0.998973
# ...                      ...                    ...
# 6814                0.604455               0.998992
# 6815                0.598308               0.998992
# 6816                0.610444               0.998984
# 6817                0.607850               0.999074
# 6818                0.627409               0.998080
#
#       Non-industry income and expenditure/revenue  Operating Expense Rate  \
# 0                                        0.302646            1.256969e-04
# 1                                        0.303556            2.897851e-04
# 2                                        0.302035            2.361297e-04
# 3                                        0.303350            1.078888e-04
# 4                                        0.303475            7.890000e+09
# ...                                           ...                     ...
# 6814                                     0.303510            1.510213e-04
# 6815                                     0.303520            5.220000e+09
# 6816                                     0.303512            2.509312e-04
# 6817                                     0.303498            1.236154e-04
# 6818                                     0.313415            1.431695e-03
#
#       Research and development expense rate  Cash flow rate  \
# 0                              0.000000e+00        0.458143
# 1                              0.000000e+00        0.461867
# 2                              2.550000e+07        0.458521
# 3                              0.000000e+00        0.465705
# 4                              0.000000e+00        0.462746
# ...                                     ...             ...
# 6814                           4.500000e+09        0.463734
# 6815                           1.440000e+09        0.461978
# 6816                           1.039086e-04        0.472189
# 6817                           2.510000e+09        0.476123
# 6818                           0.000000e+00        0.427721
#
#       Interest-bearing debt interest rate  Tax rate (A)  ...  \
# 0                            7.250725e-04      0.000000  ...
# 1                            6.470647e-04      0.000000  ...
# 2                            7.900790e-04      0.000000  ...
# 3                            4.490449e-04      0.000000  ...
# 4                            6.860686e-04      0.000000  ...
# ...                                   ...           ...  ...
# 6814                         1.790179e-04      0.113372  ...
# 6815                         2.370237e-04      0.371596  ...
# 6816                         0.000000e+00      0.490839  ...
# 6817                         2.110211e-04      0.181294  ...
# 6818                         5.900000e+08      0.000000  ...
#
#       Cash Flow to Total Assets  Cash Flow to Equity  \
# 0                      0.637555             0.312905
# 1                      0.641100             0.314163
# 2                      0.642765             0.314515
# 3                      0.579039             0.302382
# 4                      0.622374             0.311567
# ...                         ...                  ...
# 6814                   0.639806             0.314063
# 6815                   0.642072             0.314446
# 6816                   0.631678             0.313353
# 6817                   0.684857             0.320118
# 6818                   0.659917             0.316238
#
#       Current Liability to Current Assets  Liability-Assets Flag  \
# 0                                0.118250                      0
# 1                                0.047775                      0
# 2                                0.025346                      0
# 3                                0.067250                      0
# 4                                0.047725                      0
# ...                                   ...                    ...
# 6814                             0.027951                      0
# 6815                             0.031470                      0
# 6816                             0.007542                      0
# 6817                             0.022916                      0
# 6818                             0.005579                      0
#
#       Total assets to GNP price  No-credit Interval  \
# 0                      0.009219            0.622879
# 1                      0.008323            0.623652
# 2                      0.040003            0.623841
# 3                      0.003252            0.622929
# 4                      0.003878            0.623521
# ...                         ...                 ...
# 6814                   0.000466            0.623620
# 6815                   0.001959            0.623931
# 6816                   0.002840            0.624156
# 6817                   0.002837            0.623957
# 6818                   0.000707            0.626680
#
#       Degree of Financial Leverage (DFL)  \
# 0                               0.026601
# 1                               0.264577
# 2                               0.026555
# 3                               0.026697
# 4                               0.024752
# ...                                  ...
# 6814                            0.027064
# 6815                            0.027009
# 6816                            0.026791
# 6817                            0.026822
# 6818                            0.026793
#
#       Interest Coverage Ratio (Interest expense to EBIT)  Net Income Flag  \
# 0                                              0.564050                 1
# 1                                              0.570175                 1
# 2                                              0.563706                 1
# 3                                              0.564663                 1
# 4                                              0.575617                 1
# ...                                                 ...               ...
# 6814                                           0.566193                 1
# 6815                                           0.566018                 1
# 6816                                           0.565158                 1
# 6817                                           0.565302                 1
# 6818                                           0.565167                 1
#
#       Equity to Liability
# 0                0.016469
# 1                0.020794
# 2                0.016474
# 3                0.023982
# 4                0.035490
# ...                   ...
# 6814             0.029890
# 6815             0.038284
# 6816             0.097649
# 6817             0.044009
# 6818             0.233902
#
# [6819 rows x 62 columns]

# %%
correlations_drpmatrix = data_dropped.corr()
bankruptcy_correlations = correlations_matrix['Bankrupt?'].sort_values()

bankruptcy_correlations.tail(10)
# Out:
# Liability-Assets Flag                  0.139212
# Current Liability to Equity            0.153828
# Current Liabilities/Equity             0.153828
# Liability to Equity                    0.166812
# Current Liability to Current Assets    0.171306
# Borrowing dependency                   0.176543
# Current Liability to Assets            0.194494
# Debt_ratio                             0.250161
# Bankrupt?                              1.000000
# Net Income Flag                             NaN
# Name: Bankrupt?, dtype: float64

# %% [markdown]
# ## 2. Dropping Low Variance Features

# %%
variances = data.var()

sorted_variances = variances.sort_values(ascending=False)

print(sorted_variances.head(10))
# Out:
# Quick Asset Turnover Rate                1.139025e+19
# Inventory Turnover Rate (times)          1.054929e+19
# Operating Expense Rate                   1.048260e+19
# Cash Turnover Rate                       8.635506e+18
# Total Asset Growth Rate                  8.396768e+18
# Current Asset Turnover Rate              7.958951e+18
# Research and development expense rate    6.751119e+18
# Fixed Assets Turnover Frequency          6.138290e+18
# Inventory/Current Liability              3.387840e+17
# Long-term Liability to Current Assets    3.252086e+17
# dtype: float64

# %%
test_variance_threshold = 0.02

low_variance_columns = variances[variances <= test_variance_threshold].index.tolist()

test_high_variance = data.drop(columns=low_variance_columns)

print(f"Dropped columns: {low_variance_columns}")
print(test_high_variance.head())
# Out:
# Dropped columns: ['ROA(C) before interest and depreciation before interest', 'ROA(A) before interest and % after tax', 'ROA(B) before interest and depreciation after tax', 'Operating Gross Margin', 'Realized Sales Gross Margin', 'Operating Profit Rate', 'Pre-tax net Interest Rate', 'After-tax net Interest Rate', 'Non-industry income and expenditure/revenue', 'Continuous interest rate (after tax)', 'Cash flow rate', 'Tax rate (A)', 'Net Value Per Share (B)', 'Net Value Per Share (A)', 'Net Value Per Share (C)', 'Persistent EPS in the Last Four Seasons', 'Cash Flow Per Share', 'Operating Profit Per Share (Yuan ¥)', 'Per Share Net profit before tax (Yuan ¥)', 'Realized Sales Gross Profit Growth Rate', 'Operating Profit Growth Rate', 'After-tax Net Profit Growth Rate', 'Regular Net Profit Growth Rate', 'Continuous Net Profit Growth Rate', 'Total Asset Return Growth Rate Ratio', 'Cash Reinvestment %', 'Interest Expense Ratio', 'Debt_ratio', 'Net worth/Assets', 'Long-term fund suitability ratio (A)', 'Borrowing dependency', 'Contingent liabilities/Net worth', 'Operating profit/Paid-in capital', 'Net profit before tax/Paid-in capital', 'Inventory and accounts receivable/Net value', 'Total Asset Turnover', 'Net Worth Turnover Rate (times)', 'Operating profit per person', 'Working Capital to Total Assets', 'Cash/Total Assets', 'Current Liability to Assets', 'Operating Funds to Liability', 'Inventory/Working Capital', 'Working Capital/Equity', 'Current Liabilities/Equity', 'Retained Earnings to Total Assets', 'Total income/Total expense', 'Total expense/Assets', 'Working capitcal Turnover Rate', 'Cash Flow to Sales', 'Current Liability to Equity', 'Equity to Long-term Liability', 'Cash Flow to Total Assets', 'Cash Flow to Liability', 'CFO to Assets', 'Cash Flow to Equity', 'Current Liability to Current Assets', 'Liability-Assets Flag', 'Net Income to Total Assets', 'No-credit Interval', 'Gross Profit to Sales', "Net Income to Stockholder's Equity", 'Liability to Equity', 'Degree of Financial Leverage (DFL)', 'Interest Coverage Ratio (Interest expense to EBIT)', 'Net Income Flag', 'Equity to Liability']
#    Bankrupt?  Operating Expense Rate  Research and development expense rate  \
# 0          1            1.256969e-04                                    0.0
# 1          1            2.897851e-04                                    0.0
# 2          1            2.361297e-04                             25500000.0
# 3          1            1.078888e-04                                    0.0
# 4          1            7.890000e+09                                    0.0
#
#    Interest-bearing debt interest rate  Revenue Per Share (Yuan ¥)  \
# 0                             0.000725                    0.017560
# 1                             0.000647                    0.021144
# 2                             0.000790                    0.005944
# 3                             0.000449                    0.014368
# 4                             0.000686                    0.029690
#
#    Total Asset Growth Rate  Net Value Growth Rate  Current Ratio  Quick Ratio  \
# 0             4.980000e+09               0.000327       0.002259     0.001208
# 1             6.110000e+09               0.000443       0.006016     0.004039
# 2             7.280000e+09               0.000396       0.011543     0.005348
# 3             4.880000e+09               0.000382       0.004194     0.002896
# 4             5.510000e+09               0.000439       0.006022     0.003727
#
#    Total debt/Total net worth  ...  Cash/Current Liability  \
# 0                    0.021266  ...            1.473360e-04
# 1                    0.012502  ...            1.383910e-03
# 2                    0.021248  ...            5.340000e+09
# 3                    0.009572  ...            1.010646e-03
# 4                    0.005150  ...            6.804636e-04
#
#    Inventory/Current Liability  Current Liabilities/Liability  \
# 0                     0.001036                       0.676269
# 1                     0.005210                       0.308589
# 2                     0.013879                       0.446027
# 3                     0.003540                       0.615848
# 4                     0.004869                       0.975007
#
#    Long-term Liability to Current Assets  Current Asset Turnover Rate  \
# 0                               0.025592                 7.010000e+08
# 1                               0.023947                 1.065198e-04
# 2                               0.003715                 1.791094e-03
# 3                               0.022165                 8.140000e+09
# 4                               0.000000                 6.680000e+09
#
#    Quick Asset Turnover Rate  Cash Turnover Rate  Fixed Assets to Assets  \
# 0               6.550000e+09        4.580000e+08                0.424206
# 1               7.700000e+09        2.490000e+09                0.468828
# 2               1.022676e-03        7.610000e+08                0.276179
# 3               6.050000e+09        2.030000e+09                0.559144
# 4               5.050000e+09        8.240000e+08                0.309555
#
#    Current Liability to Liability  Total assets to GNP price
# 0                        0.676269                   0.009219
# 1                        0.308589                   0.008323
# 2                        0.446027                   0.040003
# 3                        0.615848                   0.003252
# 4                        0.975007                   0.003878
#
# [5 rows x 29 columns]

# %%
test_high_variance.head()
# Out:
#    Bankrupt?  Operating Expense Rate  Research and development expense rate  \
# 0          1            1.256969e-04                                    0.0
# 1          1            2.897851e-04                                    0.0
# 2          1            2.361297e-04                             25500000.0
# 3          1            1.078888e-04                                    0.0
# 4          1            7.890000e+09                                    0.0
#
#    Interest-bearing debt interest rate  Revenue Per Share (Yuan ¥)  \
# 0                             0.000725                    0.017560
# 1                             0.000647                    0.021144
# 2                             0.000790                    0.005944
# 3                             0.000449                    0.014368
# 4                             0.000686                    0.029690
#
#    Total Asset Growth Rate  Net Value Growth Rate  Current Ratio  Quick Ratio  \
# 0             4.980000e+09               0.000327       0.002259     0.001208
# 1             6.110000e+09               0.000443       0.006016     0.004039
# 2             7.280000e+09               0.000396       0.011543     0.005348
# 3             4.880000e+09               0.000382       0.004194     0.002896
# 4             5.510000e+09               0.000439       0.006022     0.003727
#
#    Total debt/Total net worth  ...  Cash/Current Liability  \
# 0                    0.021266  ...            1.473360e-04
# 1                    0.012502  ...            1.383910e-03
# 2                    0.021248  ...            5.340000e+09
# 3                    0.009572  ...            1.010646e-03
# 4                    0.005150  ...            6.804636e-04
#
#    Inventory/Current Liability  Current Liabilities/Liability  \
# 0                     0.001036                       0.676269
# 1                     0.005210                       0.308589
# 2                     0.013879                       0.446027
# 3                     0.003540                       0.615848
# 4                     0.004869                       0.975007
#
#    Long-term Liability to Current Assets  Current Asset Turnover Rate  \
# 0                               0.025592                 7.010000e+08
# 1                               0.023947                 1.065198e-04
# 2                               0.003715                 1.791094e-03
# 3                               0.022165                 8.140000e+09
# 4                               0.000000                 6.680000e+09
#
#    Quick Asset Turnover Rate  Cash Turnover Rate  Fixed Assets to Assets  \
# 0               6.550000e+09        4.580000e+08                0.424206
# 1               7.700000e+09        2.490000e+09                0.468828
# 2               1.022676e-03        7.610000e+08                0.276179
# 3               6.050000e+09        2.030000e+09                0.559144
# 4               5.050000e+09        8.240000e+08                0.309555
#
#    Current Liability to Liability  Total assets to GNP price
# 0                        0.676269                   0.009219
# 1                        0.308589                   0.008323
# 2                        0.446027                   0.040003
# 3                        0.615848                   0.003252
# 4                        0.975007                   0.003878
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 3. PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd


scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)


pca = PCA(n_components=2)  
pca_result = pca.fit_transform(data_scaled)


pca_df = pd.DataFrame(data=pca_result, columns=['Principal Component 1', 'Principal Component 2'])



print(pca_df.head())

print(f"Explained variance by component: {pca.explained_variance_ratio_}")
# Out:
#    Principal Component 1  Principal Component 2
# 0              -7.805386               0.516750
# 1              -3.179078              -0.819643
# 2              -4.782745              -0.244330
# 3              -6.294096              -1.236107
# 4              -2.819902              -0.035575
# Explained variance by component: [0.13304217 0.07144656]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(pca_df['Principal Component 1'], pca_df['Principal Component 2'])  
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Result')
plt.show()

# %% [markdown]
# ## CSV EXPORT :

# %%
#1. CSV without highly correlated columns: 
data_dropped.to_csv('low_correl_data.csv', index=False)

# %%
#2. CSV without low variance columns: 
test_high_variance.to_csv('low_var_data.csv', index=False)

# %%
#3. CSV with PCA reduction: 
pca_df.to_csv('pca_data.csv', index=False)
